# %% [markdown]
# # Figure: A Core Urban Microbiome

# %%
# %load_ext rpy2.ipython

import pandas as pd
from metasub_utils.packet_parse import MetaSUBTableFactory
from capalyzer.packet_parser.experimental import umap
import warnings
from os.path import isfile

warnings.filterwarnings('ignore')

core_tabler = MetaSUBTableFactory.core_factory()
# Out:
# /home/dcdanko/miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
# %%R
#
# library(ggthemes)
# library(ggplot2)
# library(reshape2)
# library(gridExtra)
# library(ALDEx2)
# library(RColorBrewer)

# %%
taxa = core_tabler.taxonomy(strict='medium')
print(taxa.shape)

def prevalence(df, thresh=0, count=False):
    """Return the prevalence of each column in a dataframe."""
    return (df > thresh).sum(axis=0) / (1 if count else df.shape[0])

prev = pd.DataFrame({
    'total': prevalence(taxa),
    'city': taxa.groupby(by=core_tabler.metadata['city']).apply(prevalence).mean(axis=0),
    'continent': taxa.groupby(by=core_tabler.metadata['continent']).apply(prevalence).mean(axis=0),
})
prev['taxa'] = prev.index
print(prev.shape)
prev_flat = prev.melt(id_vars='taxa')
prev_flat.head()

pt = prev_flat.query('variable == "total"')
print(pt.query('value < 0.25').shape)
print(pt.query('value < 0.9').query('value > 0.25').shape)
print(pt.query('value > 0.9').shape)
# Out:
# (3528, 3884)
# (3884, 4)
# (2545, 3)
# (1261, 3)
# (78, 3)

# %%
prev.loc['Cupriavidus metallidurans']
# Out:
# total                         0.723639
# city                          0.802183
# continent                     0.666267
# taxa         Cupriavidus metallidurans
# Name: Cupriavidus metallidurans, dtype: object

# %%
prev.loc['Cutibacterium acnes']
# Out:
# total                   0.996315
# city                    0.999019
# continent               0.995566
# taxa         Cutibacterium acnes
# Name: Cutibacterium acnes, dtype: object

# %%
prev.loc['Candida dubliniensis']
# Out:
# total                    0.545068
# city                     0.623806
# continent                0.582605
# taxa         Candida dubliniensis
# Name: Candida dubliniensis, dtype: object

# %%
sorted(list(prev.query('total > 0.9')['taxa']))
# Out:
# ['Acinetobacter johnsonii',
#  'Acinetobacter junii',
#  'Acinetobacter schindleri',
#  'Actinomyces oris',
#  'Actinomyces radicidentis',
#  'Actinomyces sp. oral taxon 414',
#  'Arsenicicoccus sp. oral taxon 190',
#  'Blastococcus saxobsidens',
#  'Brachybacterium faecium',
#  'Brachybacterium ginsengisoli',
#  'Brachybacterium sp. P6-10-X1',
#  'Brevibacterium linens',
#  'Brevundimonas naejangsanensis',
#  'Brevundimonas sp. DS20',
#  'Brevundimonas sp. GW460-12-10-14-LB2',
#  'Brevundimonas vesicularis',
#  'Cellulosimicrobium sp. TH-20',
#  'Chryseobacterium taklimakanense',
#  'Corynebacterium doosanense',
#  'Corynebacterium ureicelerivorans',
#  'Corynebacterium variabile',
#  'Curtobacterium sp. MR_MD2014',
#  'Cutibacterium acnes',
#  'Cutibacterium avidum',
#  'Cutibacterium granulosum',
#  'Delftia tsuruhatensis',
#  'Dermacoccus nishinomiyaensis',
#  'Dietzia timorensis',
#  'Geodermatophilus obscurus',
#  'Gordonia bronchialis',
#  'Isoptericola variabilis',
#  'Janibacter indicus',
#  'Kocuria flava',
#  'Kocuria palustris',
#  'Kocuria rhizophila',
#  'Kytococcus sedentarius',
#  'Microbacterium aurum',
#  'Microbacterium chocolatum',
#  'Microbacterium hominis',
#  'Microbacterium paludicola',
#  'Microbacterium sp. No. 7',
#  'Microbacterium sp. PAMC 28756',
#  'Microbacterium sp. TPU 3598',
#  'Micrococcus luteus',
#  'Modestobacter marinus',
#  'Moraxella osloensis',
#  'Nocardioides dokdonensis',
#  'Ochrobactrum anthropi',
#  'Paracoccus sp. CBA4604',
#  'Paracoccus yeei',
#  'Propionibacterium freudenreichii',
#  'Pseudomonas aeruginosa',
#  'Pseudomonas aeruginosa group',
#  'Pseudomonas alcaligenes',
#  'Pseudomonas alcaliphila',
#  'Pseudomonas oleovorans/pseudoalcaligenes group',
#  'Pseudomonas pseudoalcaligenes',
#  'Pseudomonas stutzeri',
#  'Pseudomonas stutzeri group',
#  'Pseudomonas stutzeri subgroup',
#  'Roseomonas sp. FDAARGOS_362',
#  'Rothia dentocariosa',
#  'Rothia mucilaginosa',
#  'Serinicoccus sp. JLT9',
#  'Sphingobium yanoikuyae',
#  'Staphylococcus capitis',
#  'Staphylococcus epidermidis',
#  'Staphylococcus haemolyticus',
#  'Staphylococcus hominis',
#  'Staphylococcus saprophyticus',
#  'Stenotrophomonas acidaminiphila',
#  'Stenotrophomonas maltophilia',
#  'Stenotrophomonas rhizophila',
#  'Stenotrophomonas sp. LM091',
#  'Tessaracoccus aquimaris',
#  'Tessaracoccus flavescens',
#  'Tessaracoccus flavus',
#  'Tessaracoccus sp. T2.5-30']

# %%
# %%R -w 1920 -h 1920
#
# ### Core tree METASUB 2019
# ## Author Maria A. Sierra
#
# library(ape)
# library(ggtree)
# library(ggplot2)
# library(tidyr)
#
# #Data
# tax<-read.table("/home/dcdanko/Dropbox/resources_and_shared/release_packet_jun12_2019/taxonomy/core_taxa/taxonomy.txt") #Taxonomy of the tree
# ring<-read.table("/home/dcdanko/Dropbox/resources_and_shared/release_packet_jun12_2019/taxonomy/core_taxa/core_ring.txt", sep = "") #Heatmap ring
# phylum<-read.table("/home/dcdanko/Dropbox/resources_and_shared/release_packet_jun12_2019/taxonomy/core_taxa/phyla.txt") #Phylum of each taxa
# tree.core<-read.nexus("/home/dcdanko/Dropbox/resources_and_shared/release_packet_jun12_2019/taxonomy/core_taxa/tree.txt") ##Nexus tree
#
# df <- data.frame(taxa = tax, Phylum=phylum, ring=ring)
# row.names(df) <- NULL
#
# #Create ggtree
# gt = ggtree(tree.core, layout="circular", open.angle=T, aes(colour=Phylum), size=1) %<+% df +
#     xlim(1,20) +
#    geom_tiplab2(size=6, align = T, linetype=NA, colour="black", aes(angle=angle), offset = 1.8, hjust = 0) +
#    scale_colour_manual(
#         values =c("#8DD3C7","#ffea80","#BEBADA","#FB8072","#80B1D3", "#FDB462","#B3DE69","#FCCDE5","#D9D9D9"),
#         na.value="black",
#         breaks=c("Actinobacteria", "Firmicutes", "Proteobacteria","Ascomycota","Euglenozoa")
#    )
# #Heatmap ring
# gheatmap(gt, ring, offset = 0,width=0.08,font.size=3.5,
#          colnames_offset_y = 6,
#          colnames_angle=90,
#          colnames_position = "top", hjust = 1)+
#   scale_fill_brewer(palette = "Accent", na.value="gray90",breaks=c("Yes","No","Positive", "Negative")) +
#   theme_tree(text = element_text(size=50),
#               legend.position="right",
#              legend.text = element_text(colour="gray30", size = 26),
#              legend.title=element_text(size = 50),
#              legend.key.size=unit(2,"line")) +
#   guides(colour = guide_legend(override.aes = list(size=5)),
#          fill=guide_legend(ncol=2)) +
#   labs(fill = "Commensal  Gram Stain")

# %%
# %%R -i prev_flat -h 540 -w 540
#
# ggplot(prev_flat, aes(x=value, color=variable)) +
#     geom_density(size=2) +
#     theme_minimal() +
#     xlab('Species Prevalence') +
#     ylab('Density') +
#     geom_vline(xintercept=0.25, color='black') +
#     geom_vline(xintercept=0.9, color='black') +
#     annotate(geom='label', x=0.5, y=3.2, label="Pan (1,305)", size=10) +
#     annotate(geom='label', x=0.25, y=3.5, label="Peripheral (2,224)", size=10) +
#     annotate(geom='label', x=0.85, y=3.5, label="Core (158)", size=10) +
#     scale_color_brewer(palette = "Set1") +
#     theme(
#         text=element_text(size=20),
#         axis.text.x=element_text(angle = 0, hjust = 1)
#     )

# %%
list(prev_flat.query('value > 0.9').query('variable =="total"')['taxa'])
# Out:
# ['Enterobacter cloacae',
#  'Klebsiella pneumoniae',
#  'Leclercia adecarboxylata',
#  'Salmonella enterica',
#  'Escherichia coli',
#  'Serratia marcescens',
#  'Acinetobacter schindleri',
#  'Acinetobacter johnsonii',
#  'Acinetobacter junii',
#  'Acinetobacter haemolyticus',
#  'Acinetobacter baumannii',
#  'Acinetobacter pittii',
#  'Moraxella osloensis',
#  'Pseudomonas koreensis',
#  'Pseudomonas psychrotolerans',
#  'Pseudomonas alcaliphila',
#  'Pseudomonas sp. URMO17WK12:I11',
#  'Pseudomonas stutzeri',
#  'Pseudomonas aeruginosa',
#  'Pseudomonas mendocina',
#  'Pseudomonas citronellolis',
#  'Pseudomonas alcaligenes',
#  'Pseudomonas pseudoalcaligenes',
#  'Pseudomonas putida',
#  'Pseudomonas oryzihabitans',
#  'Pseudomonas fluorescens',
#  'Pseudomonas azotoformans',
#  'Pseudomonas syringae',
#  'Pseudomonas chlororaphis',
#  'Pseudomonas fragi',
#  'Stenotrophomonas rhizophila',
#  'Stenotrophomonas sp. LM091',
#  'Stenotrophomonas acidaminiphila',
#  'Stenotrophomonas maltophilia',
#  'Xanthomonas campestris',
#  'Xanthomonas translucens',
#  'Pseudoxanthomonas suwonensis',
#  'Pseudoxanthomonas spadix',
#  'Luteimonas sp. 100111',
#  'Rhizobium leguminosarum',
#  'Agrobacterium tumefaciens',
#  'Shinella sp. HZN7',
#  'Rhodopseudomonas palustris',
#  'Methylobacterium populi',
#  'Methylobacterium aquaticum',
#  'Methylobacterium extorquens',
#  'Ochrobactrum anthropi',
#  'Brevundimonas naejangsanensis',
#  'Brevundimonas sp. DS20',
#  'Brevundimonas subvibrioides',
#  'Brevundimonas sp. GW460-12-10-14-LB2',
#  'Brevundimonas sp. LM2',
#  'Brevundimonas vesicularis',
#  'Caulobacter vibrioides',
#  'Roseomonas sp. FDAARGOS_362',
#  'Roseomonas gilardii',
#  'Paracoccus yeei',
#  'Paracoccus contaminans',
#  'Paracoccus zhejiangensis',
#  'Paracoccus denitrificans',
#  'Paracoccus aminovorans',
#  'Paracoccus sp. CBA4604',
#  'Rhodobacter sphaeroides',
#  'Sphingobium yanoikuyae',
#  'Sphingobium cloacae',
#  'Sphingomonas sanxanigenens',
#  'Sphingomonas sp. LK11',
#  'Sphingomonas koreensis',
#  'Sphingomonas taxi',
#  'Sphingomonas sp. NIC1',
#  'Sphingomonas melonis',
#  'Novosphingobium resinovorum',
#  'Achromobacter xylosoxidans',
#  'Achromobacter sp. AONIH1',
#  'Massilia sp. WG5',
#  'Massilia putida',
#  'Comamonas testosteroni',
#  'Variovorax paradoxus',
#  'Delftia tsuruhatensis',
#  'Ramlibacter tataouinensis',
#  'Neisseria sicca',
#  'Staphylococcus aureus',
#  'Staphylococcus hominis',
#  'Staphylococcus epidermidis',
#  'Staphylococcus capitis',
#  'Staphylococcus haemolyticus',
#  'Staphylococcus saprophyticus',
#  'Streptococcus mitis',
#  'Streptococcus oralis',
#  'Streptococcus gordonii',
#  'Lactococcus lactis',
#  'Kocuria flava',
#  'Kocuria palustris',
#  'Kocuria rhizophila',
#  'Micrococcus luteus',
#  'Rothia mucilaginosa',
#  'Rothia dentocariosa',
#  'Microbacterium aurum',
#  'Microbacterium sp. PAMC 28756',
#  'Microbacterium sp. TPU 3598',
#  'Microbacterium paludicola',
#  'Microbacterium sp. No. 7',
#  'Microbacterium sp. BH-3-3-3',
#  'Microbacterium hominis',
#  'Microbacterium chocolatum',
#  'Curtobacterium sp. MR_MD2014',
#  'Curtobacterium pusillum',
#  'Leifsonia xyli',
#  'Cellulosimicrobium sp. TH-20',
#  'Cellulosimicrobium cellulans',
#  'Isoptericola variabilis',
#  'Janibacter indicus',
#  'Serinicoccus sp. JLT9',
#  'Arsenicicoccus sp. oral taxon 190',
#  'Cellulomonas fimi',
#  'Cellulomonas sp. PSBB021',
#  'Cellulomonas flavigena',
#  'Cellulomonas gilvus',
#  'Brachybacterium ginsengisoli',
#  'Brachybacterium faecium',
#  'Brachybacterium sp. P6-10-X1',
#  'Sanguibacter keddieii',
#  'Kytococcus sedentarius',
#  'Dermacoccus nishinomiyaensis',
#  'Brevibacterium linens',
#  'Corynebacterium singulare',
#  'Corynebacterium ureicelerivorans',
#  'Corynebacterium variabile',
#  'Corynebacterium jeikeium',
#  'Gordonia bronchialis',
#  'Dietzia timorensis',
#  'Cutibacterium acnes',
#  'Cutibacterium granulosum',
#  'Cutibacterium avidum',
#  'Tessaracoccus flavescens',
#  'Tessaracoccus aquimaris',
#  'Tessaracoccus sp. T2.5-30',
#  'Tessaracoccus flavus',
#  'Microlunatus phosphovorus',
#  'Propionibacterium freudenreichii',
#  'Propionibacterium sp. oral taxon 193',
#  'Acidipropionibacterium acidipropionici',
#  'Nocardioides dokdonensis',
#  'Nocardioides sp. 78',
#  'Nocardioides sp. JS614',
#  'Pimelobacter simplex',
#  'Actinoalloteichus sp. AHMU CJ021',
#  'Geodermatophilus obscurus',
#  'Modestobacter marinus',
#  'Blastococcus saxobsidens',
#  'Actinomyces sp. oral taxon 414',
#  'Actinomyces oris',
#  'Nakamurella multipartita',
#  'Kineococcus radiotolerans',
#  'Candida dubliniensis',
#  'Thielavia terrestris',
#  'Thermothelomyces thermophila',
#  'Leishmania major']

# %%
taxa = core_tabler.taxonomy(normalize=True)

city_medians = taxa.groupby(by=core_tabler.metadata['city']).median()

#top_taxa = city_medians.median().sort_values(ascending=False)[:50].index
#top_taxa = city_medians.mean().sort_values(ascending=False)[:50].index
top_taxa = taxa.mean().sort_values(ascending=False)[:75].index
taxa, city_medians = taxa[top_taxa], city_medians[top_taxa]

taxa_prev = (core_tabler.taxonomy(normalize=True) > 0).mean()[top_taxa]
city_prev_medians = (taxa.groupby(by=core_tabler.metadata['city']).median() > 0).mean()[top_taxa]

taxa = 1000 * 1000 * taxa
city_medians = 1000 * 1000 * city_medians
taxa_mean = taxa.mean()
taxa_kurtosis = taxa.kurtosis()
taxa_sd = taxa.std()

def add_stats(taxon):
    m, k, sd = taxa_mean[taxon], taxa_kurtosis[taxon], taxa_sd[taxon]
    return f'{taxon} OPCC{m // 1000:.0f}kCCC {sd // 1000:.0f}kCCC {k:.0f}CPCC'

top_taxa2 = top_taxa.copy()
taxa_stats = pd.Series({taxon: add_stats(taxon) for taxon in taxa.columns})
taxa.columns = [taxa_stats[taxon] for taxon in taxa.columns]
city_medians.columns = [taxa_stats[taxon] for taxon in city_medians.columns]
top_taxa = top_taxa.map(lambda x: taxa_stats[x])
taxa.head()
# Out:
#                                                     Negativicoccus massiliensis OPCC104kCCC 178kCCC 4CPCC  \
# haib17DB4959_H3MGVCCXY_SL259952                                                              0.000000
# haib18CEM5526_HMGMHCCXY_SL343397                                                        215828.720492
# haib18CEM5453_HMC2KCCXY_SL336787                                                             0.000000
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                           0.000000
# haib18CEM5453_HT5YVCCXY_SL357487                                                             0.000000
#
#                                                     Cutibacterium acnes OPCC100kCCC 141kCCC 6CPCC  \
# haib17DB4959_H3MGVCCXY_SL259952                                                       4553.407488
# haib18CEM5526_HMGMHCCXY_SL343397                                                    296114.452785
# haib18CEM5453_HMC2KCCXY_SL336787                                                    125560.683450
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                    3551.625520
# haib18CEM5453_HT5YVCCXY_SL357487                                                     58370.060341
#
#                                                     Bradyrhizobium sp. BTAi1 OPCC57kCCC 102kCCC 6CPCC  \
# haib17DB4959_H3MGVCCXY_SL259952                                                         143068.984292
# haib18CEM5526_HMGMHCCXY_SL343397                                                         30688.398390
# haib18CEM5453_HMC2KCCXY_SL336787                                                        185422.230289
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                           0.000000
# haib18CEM5453_HT5YVCCXY_SL357487                                                        295516.223971
#
#                                                     Salmonella enterica OPCC31kCCC 86kCCC 26CPCC  \
# haib17DB4959_H3MGVCCXY_SL259952                                                      2027.636623
# haib18CEM5526_HMGMHCCXY_SL343397                                                     2610.143281
# haib18CEM5453_HMC2KCCXY_SL336787                                                     5210.142861
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                    152.868143
# haib18CEM5453_HT5YVCCXY_SL357487                                                   138219.873994
#
#                                                     Pseudomonas stutzeri OPCC25kCCC 103kCCC 45CPCC  \
# haib17DB4959_H3MGVCCXY_SL259952                                                         128.605120
# haib18CEM5526_HMGMHCCXY_SL343397                                                       3346.455785
# haib18CEM5453_HMC2KCCXY_SL336787                                                       3491.145739
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                      152.207806
# haib18CEM5453_HT5YVCCXY_SL357487                                                        422.422208
#
#                                                     Micrococcus luteus OPCC23kCCC 41kCCC 113CPCC  \
# haib17DB4959_H3MGVCCXY_SL259952                                                       221.829793
# haib18CEM5526_HMGMHCCXY_SL343397                                                    40288.130304
# haib18CEM5453_HMC2KCCXY_SL336787                                                    39972.516788
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                    110.606540
# haib18CEM5453_HT5YVCCXY_SL357487                                                     4454.382099
#
#                                                     Pseudomonas fluorescens OPCC15kCCC 83kCCC 58CPCC  \
# haib17DB4959_H3MGVCCXY_SL259952                                                            86.766337
# haib18CEM5526_HMGMHCCXY_SL343397                                                         3732.289686
# haib18CEM5453_HMC2KCCXY_SL336787                                                          537.996837
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                     940677.585568
# haib18CEM5453_HT5YVCCXY_SL357487                                                          440.908956
#
#                                                     Moraxella osloensis OPCC10kCCC 33kCCC 432CPCC  \
# haib17DB4959_H3MGVCCXY_SL259952                                                         44.927553
# haib18CEM5526_HMGMHCCXY_SL343397                                                      7215.555101
# haib18CEM5453_HMC2KCCXY_SL336787                                                     39256.916176
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                    1245.066453
# haib18CEM5453_HT5YVCCXY_SL357487                                                     12396.289340
#
#                                                     Cupriavidus metallidurans OPCC9kCCC 19kCCC 20CPCC  \
# haib17DB4959_H3MGVCCXY_SL259952                                                          28780.871196
# haib18CEM5526_HMGMHCCXY_SL343397                                                           172.164928
# haib18CEM5453_HMC2KCCXY_SL336787                                                         32978.557909
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                           4.622363
# haib18CEM5453_HT5YVCCXY_SL357487                                                         60201.172799
#
#                                                     Janibacter indicus OPCC8kCCC 33kCCC 135CPCC  \
# haib17DB4959_H3MGVCCXY_SL259952                                                       51.105091
# haib18CEM5526_HMGMHCCXY_SL343397                                                    3340.307038
# haib18CEM5453_HMC2KCCXY_SL336787                                                   10337.317535
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                    24.432489
# haib18CEM5453_HT5YVCCXY_SL357487                                                     457.547030
#
#                                                     ...  \
# haib17DB4959_H3MGVCCXY_SL259952                     ...
# haib18CEM5526_HMGMHCCXY_SL343397                    ...
# haib18CEM5453_HMC2KCCXY_SL336787                    ...
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...  ...
# haib18CEM5453_HT5YVCCXY_SL357487                    ...
#
#                                                     Sphingobium yanoikuyae OPCC2kCCC 18kCCC 1039CPCC  \
# haib17DB4959_H3MGVCCXY_SL259952                                                            61.213791
# haib18CEM5526_HMGMHCCXY_SL343397                                                          913.088992
# haib18CEM5453_HMC2KCCXY_SL336787                                                         3024.449688
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                         25.753165
# haib18CEM5453_HT5YVCCXY_SL357487                                                          541.661737
#
#                                                     Nocardioides dokdonensis OPCC2kCCC 2kCCC 4CPCC  \
# haib17DB4959_H3MGVCCXY_SL259952                                                          24.429357
# haib18CEM5526_HMGMHCCXY_SL343397                                                       1025.303633
# haib18CEM5453_HMC2KCCXY_SL336787                                                       1362.493194
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                        5.612869
# haib18CEM5453_HT5YVCCXY_SL357487                                                        131.255916
#
#                                                     Bacillus subtilis OPCC2kCCC 14kCCC 492CPCC  \
# haib17DB4959_H3MGVCCXY_SL259952                                                     201.612394
# haib18CEM5526_HMGMHCCXY_SL343397                                                     47.652793
# haib18CEM5453_HMC2KCCXY_SL336787                                                      0.000000
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                   30.045359
# haib18CEM5453_HT5YVCCXY_SL357487                                                      0.000000
#
#                                                     Methylobacterium aquaticum OPCC2kCCC 4kCCC 96CPCC  \
# haib17DB4959_H3MGVCCXY_SL259952                                                            424.565375
# haib18CEM5526_HMGMHCCXY_SL343397                                                           763.981867
# haib18CEM5453_HMC2KCCXY_SL336787                                                          1777.334128
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                           0.000000
# haib18CEM5453_HT5YVCCXY_SL357487                                                          2461.510589
#
#                                                     Deinococcus swuensis OPCC2kCCC 8kCCC 249CPCC  \
# haib17DB4959_H3MGVCCXY_SL259952                                                        14.039860
# haib18CEM5526_HMGMHCCXY_SL343397                                                      438.098254
# haib18CEM5453_HMC2KCCXY_SL336787                                                      986.543597
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                      0.000000
# haib18CEM5453_HT5YVCCXY_SL357487                                                      192.262186
#
#                                                     Streptococcus mitis OPCC1kCCC 4kCCC 257CPCC  \
# haib17DB4959_H3MGVCCXY_SL259952                                                       15.163049
# haib18CEM5526_HMGMHCCXY_SL343397                                                    2999.051556
# haib18CEM5453_HMC2KCCXY_SL336787                                                     536.700459
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                   119.851266
# haib18CEM5453_HT5YVCCXY_SL357487                                                     337.383164
#
#                                                     Massilia sp. WG5 OPCC1kCCC 6kCCC 583CPCC  \
# haib17DB4959_H3MGVCCXY_SL259952                                                   126.358743
# haib18CEM5526_HMGMHCCXY_SL343397                                                  740.924065
# haib18CEM5453_HMC2KCCXY_SL336787                                                  624.854157
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                  0.000000
# haib18CEM5453_HT5YVCCXY_SL357487                                                  546.283424
#
#                                                     Enterobacter cloacae OPCC1kCCC 14kCCC 603CPCC  \
# haib17DB4959_H3MGVCCXY_SL259952                                                          0.000000
# haib18CEM5526_HMGMHCCXY_SL343397                                                       487.288233
# haib18CEM5453_HMC2KCCXY_SL336787                                                       239.829915
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                      82.212025
# haib18CEM5453_HT5YVCCXY_SL357487                                                       490.823178
#
#                                                     Acinetobacter pittii OPCC1kCCC 19kCCC 759CPCC  \
# haib17DB4959_H3MGVCCXY_SL259952                                                         11.231888
# haib18CEM5526_HMGMHCCXY_SL343397                                                       773.204988
# haib18CEM5453_HMC2KCCXY_SL336787                                                       283.906764
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                     867.353374
# haib18CEM5453_HT5YVCCXY_SL357487                                                        18.486749
#
#                                                     Brevundimonas vesicularis OPCC1kCCC 5kCCC 411CPCC
# haib17DB4959_H3MGVCCXY_SL259952                                                             36.503637
# haib18CEM5526_HMGMHCCXY_SL343397                                                           787.039670
# haib18CEM5453_HMC2KCCXY_SL336787                                                          4641.032954
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                          12.546413
# haib18CEM5453_HT5YVCCXY_SL357487                                                          3807.345894
#
# [5 rows x 75 columns]

# %%
# %%R -i taxa -i city_medians -i taxa_stats --height 1080 --width 460
#
# taxa = melt(taxa)
# taxa$kind = 'All Samples'
# city_medians = melt(city_medians)
# city_medians$kind = 'City Median'
#
# taxa = rbind(taxa, city_medians)
# head(taxa)
# Out:
#                                      variable    value        kind
# 1 Negativicoccus.massiliensis..104k..178k..4.      0.0 All Samples
# 2 Negativicoccus.massiliensis..104k..178k..4. 215828.7 All Samples
# 3 Negativicoccus.massiliensis..104k..178k..4.      0.0 All Samples
# 4 Negativicoccus.massiliensis..104k..178k..4.      0.0 All Samples
# 5 Negativicoccus.massiliensis..104k..178k..4.      0.0 All Samples
# 6 Negativicoccus.massiliensis..104k..178k..4.      0.0 All Samples

# %%
# %%R -i taxa -i city_medians -i taxa_stats --height 1620 --width 500
#
# taxa = melt(taxa)
# taxa$kind = 'All Samples'
# city_medians = melt(city_medians)
# city_medians$kind = 'City Median'
#
# taxa = rbind(taxa, city_medians)
#
# #taxa$variable = gsub("\\.(?=\\.*)", " ", taxa$variable, perl=TRUE)
#
# levels(taxa$variable) <- gsub("\\.(?=\\.*)", " ", levels(taxa$variable), perl=T)
# levels(taxa$variable) <- gsub("OPCC", "(", levels(taxa$variable))
# levels(taxa$variable) <- gsub("CPCC", ")", levels(taxa$variable))
# levels(taxa$variable) <- gsub("CCC", ",", levels(taxa$variable))
# #taxa$variable = as.character(taxa$variable)
#
# ggplot(taxa, aes(x=value, color=kind)) +
#     geom_density(size=0.5) +
#     facet_grid(variable~., scales="free_y") +
#     theme_minimal() +
#     ylab('Density') +
#     xlab('Abundance (PPM)') +
#     scale_x_log10() +
#     scale_color_brewer(palette = "Set1") +
#     labs(color="") +
#     theme(
#         axis.text.x= element_text(angle=0, hjust=1),
#         axis.text.y= element_blank(),
#         strip.text.y= element_text(angle=0, hjust=0),
#         text = element_text(size=15),
#         panel.grid.major.x = element_line(colour = "grey",size=0.75),
#         panel.grid.major.y = element_blank(),
#         panel.grid.minor = element_blank(),
#         legend.position='bottom'
#     )

# %%
# %%R -i taxa_prev -i city_prev_medians -i top_taxa2 --height 1620 --width 100
#
# taxa_prev = data.frame(taxa_prev)
# taxa_prev$kind = 'All Samples'
# colnames(taxa_prev) = c('value', 'kind')
# taxa_prev$taxon = as.factor(rownames(taxa_prev))
#
# city_prev_medians = data.frame(city_prev_medians)
# city_prev_medians$kind = 'City Median'
# colnames(city_prev_medians) = c('value', 'kind')
# city_prev_medians$taxon = as.factor(rownames(city_prev_medians))
#
# taxa_prev = rbind(taxa_prev, city_prev_medians)
# #taxa_prev$taxon = as.factor(rownames(taxa_prev))
# taxa_prev$taxon = ordered(taxa_prev$taxon, levels=top_taxa2)
#
#
# ggplot(taxa_prev, aes(x=kind, y=value, fill=kind)) +
#     geom_col() +
#     facet_grid(taxon~., scales="free_y") +
#     theme_minimal() +
#     ylab('Prevalence') +
#     scale_fill_brewer(palette = "Set1") +
#     labs(color="") +
#     coord_flip() +
#     theme(
#         axis.text.x=element_text(angle=0, hjust=1),
#         axis.text.y=element_blank(),
#         axis.title.y=element_blank(),
#         strip.text.y=element_blank(),
#         text = element_text(size=15),
#         panel.grid.major = element_blank(),
#         #panel.grid.minor = element_blank(),
#         legend.position='bottom'
#     )

# %%
taxa = core_tabler.taxonomy(normalize=True)
taxa['continent'] = core_tabler.metadata['continent']
taxa['continent'] = [str(el) for el in taxa['continent']]

cacnes = taxa[['continent', 'Cutibacterium acnes']]
nmass =  taxa[['continent', 'Negativicoccus massiliensis']]

taxa.head()
# Out:
#                                                     Enterobacter sp. FY-07  \
# haib17DB4959_H3MGVCCXY_SL259952                                   0.000000
# haib18CEM5526_HMGMHCCXY_SL343397                                  0.000018
# haib18CEM5453_HMC2KCCXY_SL336787                                  0.000000
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                0.000000
# haib18CEM5453_HT5YVCCXY_SL357487                                  0.000000
#
#                                                     Enterobacter sp. R4-368  \
# haib17DB4959_H3MGVCCXY_SL259952                                         0.0
# haib18CEM5526_HMGMHCCXY_SL343397                                        0.0
# haib18CEM5453_HMC2KCCXY_SL336787                                        0.0
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                      0.0
# haib18CEM5453_HT5YVCCXY_SL357487                                        0.0
#
#                                                     Enterobacter sp. 638  \
# haib17DB4959_H3MGVCCXY_SL259952                                 0.000000
# haib18CEM5526_HMGMHCCXY_SL343397                                0.000043
# haib18CEM5453_HMC2KCCXY_SL336787                                0.000000
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...              0.000000
# haib18CEM5453_HT5YVCCXY_SL357487                                0.000000
#
#                                                     Enterobacter sp. CRENT-193  \
# haib17DB4959_H3MGVCCXY_SL259952                                            0.0
# haib18CEM5526_HMGMHCCXY_SL343397                                           0.0
# haib18CEM5453_HMC2KCCXY_SL336787                                           0.0
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                         0.0
# haib18CEM5453_HT5YVCCXY_SL357487                                           0.0
#
#                                                     Enterobacter sp. E20  \
# haib17DB4959_H3MGVCCXY_SL259952                                      0.0
# haib18CEM5526_HMGMHCCXY_SL343397                                     0.0
# haib18CEM5453_HMC2KCCXY_SL336787                                     0.0
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                   0.0
# haib18CEM5453_HT5YVCCXY_SL357487                                     0.0
#
#                                                     Enterobacter sp. Crenshaw  \
# haib17DB4959_H3MGVCCXY_SL259952                                           0.0
# haib18CEM5526_HMGMHCCXY_SL343397                                          0.0
# haib18CEM5453_HMC2KCCXY_SL336787                                          0.0
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                        0.0
# haib18CEM5453_HT5YVCCXY_SL357487                                          0.0
#
#                                                     Enterobacter sp. HK169  \
# haib17DB4959_H3MGVCCXY_SL259952                                        0.0
# haib18CEM5526_HMGMHCCXY_SL343397                                       0.0
# haib18CEM5453_HMC2KCCXY_SL336787                                       0.0
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                     0.0
# haib18CEM5453_HT5YVCCXY_SL357487                                       0.0
#
#                                                     Enterobacter sp. ODB01  \
# haib17DB4959_H3MGVCCXY_SL259952                                        0.0
# haib18CEM5526_HMGMHCCXY_SL343397                                       0.0
# haib18CEM5453_HMC2KCCXY_SL336787                                       0.0
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                     0.0
# haib18CEM5453_HT5YVCCXY_SL357487                                       0.0
#
#                                                     Enterobacter cloacae  \
# haib17DB4959_H3MGVCCXY_SL259952                                 0.000000
# haib18CEM5526_HMGMHCCXY_SL343397                                0.000487
# haib18CEM5453_HMC2KCCXY_SL336787                                0.000240
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...              0.000082
# haib18CEM5453_HT5YVCCXY_SL357487                                0.000491
#
#                                                     Enterobacter asburiae  \
# haib17DB4959_H3MGVCCXY_SL259952                                  0.000000
# haib18CEM5526_HMGMHCCXY_SL343397                                 0.000132
# haib18CEM5453_HMC2KCCXY_SL336787                                 0.000091
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...               0.000005
# haib18CEM5453_HT5YVCCXY_SL357487                                 0.000026
#
#                                                     ...  Chicken anemia virus  \
# haib17DB4959_H3MGVCCXY_SL259952                     ...                   0.0
# haib18CEM5526_HMGMHCCXY_SL343397                    ...                   0.0
# haib18CEM5453_HMC2KCCXY_SL336787                    ...                   0.0
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...  ...                   0.0
# haib18CEM5453_HT5YVCCXY_SL357487                    ...                   0.0
#
#                                                     Avian gyrovirus 2  \
# haib17DB4959_H3MGVCCXY_SL259952                                   0.0
# haib18CEM5526_HMGMHCCXY_SL343397                                  0.0
# haib18CEM5453_HMC2KCCXY_SL336787                                  0.0
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                0.0
# haib18CEM5453_HT5YVCCXY_SL357487                                  0.0
#
#                                                     Enterobacteria phage phiX174 sensu lato  \
# haib17DB4959_H3MGVCCXY_SL259952                                                    0.000000
# haib18CEM5526_HMGMHCCXY_SL343397                                                   0.000000
# haib18CEM5453_HMC2KCCXY_SL336787                                                   0.000000
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                                 0.000006
# haib18CEM5453_HT5YVCCXY_SL357487                                                   0.000000
#
#                                                     Parabacteroides phage YZ-2015b  \
# haib17DB4959_H3MGVCCXY_SL259952                                                0.0
# haib18CEM5526_HMGMHCCXY_SL343397                                               0.0
# haib18CEM5453_HMC2KCCXY_SL336787                                               0.0
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                             0.0
# haib18CEM5453_HT5YVCCXY_SL357487                                               0.0
#
#                                                     Soybean mild mottle virus  \
# haib17DB4959_H3MGVCCXY_SL259952                                           0.0
# haib18CEM5526_HMGMHCCXY_SL343397                                          0.0
# haib18CEM5453_HMC2KCCXY_SL336787                                          0.0
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                        0.0
# haib18CEM5453_HT5YVCCXY_SL357487                                          0.0
#
#                                                     Soybean chlorotic blotch virus  \
# haib17DB4959_H3MGVCCXY_SL259952                                                0.0
# haib18CEM5526_HMGMHCCXY_SL343397                                               0.0
# haib18CEM5453_HMC2KCCXY_SL336787                                               0.0
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                             0.0
# haib18CEM5453_HT5YVCCXY_SL357487                                               0.0
#
#                                                     Urochloa streak virus  \
# haib17DB4959_H3MGVCCXY_SL259952                                       0.0
# haib18CEM5526_HMGMHCCXY_SL343397                                      0.0
# haib18CEM5453_HMC2KCCXY_SL336787                                      0.0
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                    0.0
# haib18CEM5453_HT5YVCCXY_SL357487                                      0.0
#
#                                                     Maize streak Reunion virus  \
# haib17DB4959_H3MGVCCXY_SL259952                                            0.0
# haib18CEM5526_HMGMHCCXY_SL343397                                           0.0
# haib18CEM5453_HMC2KCCXY_SL336787                                           0.0
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                         0.0
# haib18CEM5453_HT5YVCCXY_SL357487                                           0.0
#
#                                                     Mollivirus sibericum  \
# haib17DB4959_H3MGVCCXY_SL259952                                      0.0
# haib18CEM5526_HMGMHCCXY_SL343397                                     0.0
# haib18CEM5453_HMC2KCCXY_SL336787                                     0.0
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...                   0.0
# haib18CEM5453_HT5YVCCXY_SL357487                                     0.0
#
#                                                     continent
# haib17DB4959_H3MGVCCXY_SL259952                             0
# haib18CEM5526_HMGMHCCXY_SL343397                       europe
# haib18CEM5453_HMC2KCCXY_SL336787                    east_asia
# sossowski_BarcelonaNov2018_MS052-29787-CTCTCTAC...     europe
# haib18CEM5453_HT5YVCCXY_SL357487                    east_asia
#
# [5 rows x 3688 columns]

# %%
# %%R -i cacnes -w 1920 -h 1080
#
# conts =  c(
#         'north_america',
#         'east_asia',
#         'europe',
#         'south_america',
#         'oceania',
#         'sub_saharan_africa',
#         'middle_east'
# )
# cacnes$continent = ordered(
#     cacnes$continent,
#     levels=conts
# )
#
# ggplot(cacnes[cacnes$continent %in% conts,], aes(x=continent, y=Cutibacterium.acnes, fill=continent)) +
#     geom_violin(width=1.6) +
#     geom_boxplot(fill='white', width=0.2) +
#     scale_y_sqrt() +
#     theme_minimal() +
#     scale_fill_brewer(palette='Set1') +
#     xlab('Continent') +
#     ylab('Relative Abundance of C. acnes') +
#     theme(
#         text = element_text(size=50),
#         legend.position='none',
#     )

# %%
# %%R -i nmass -w 1920 -h 1080
#
# conts = c(
#         'north_america',
#         'east_asia',
#         'europe',
#         'south_america',
#         'oceania',
#         'sub_saharan_africa',
#         'middle_east'
# )
# nmass$continent = ordered(
#     nmass$continent,
#     levels=conts
# )
#
# ggplot(nmass[nmass$continent %in% conts,], aes(x=continent, y=Negativicoccus.massiliensis, fill=continent)) +
#     geom_violin(width=1.2) +
#     geom_boxplot(fill='white', width=0.2) +
#     scale_y_sqrt() +
#     theme_minimal() +
#     scale_fill_brewer(palette='Set1') +
#     xlab('Continent') +
#     ylab('Relative Abundance of N. mass.') +
#     theme(
#         text = element_text(size=50),
#         legend.position='none',
#     )

# %%
taxa.query('continent == "oceania"')['Bradyrhizobium sp. BTAi1']
# Out:
# haib17DB4959_HMGW3CCXY_SL342497     0.067868
# haib17DB4959_HMCMJCCXY_SL336169     0.402511
# haib17DB4959_HMGW3CCXY_SL342489     0.190768
# haib17CEM4890_H75CGCCXY_SL263673    0.000000
# haib17CEM4890_H75CGCCXY_SL263676    0.000000
# haib17CEM4890_H75CGCCXY_SL263650    0.000000
# haib17CEM4890_H75CGCCXY_SL263700    0.000074
# haib17CEM4890_H75CGCCXY_SL263674    0.000000
# haib17CEM4890_H75CGCCXY_SL263661    0.000000
# haib17DB4959_HMGW3CCXY_SL342494     0.063054
# haib17DB4959_HMGW3CCXY_SL342496     0.329993
# haib17CEM4890_H75CGCCXY_SL263686    0.000000
# haib17CEM4890_H75CGCCXY_SL263638    0.000000
# haib17CEM4890_H75CGCCXY_SL263687    0.000000
# haib17CEM4890_H75CGCCXY_SL263721    0.000020
# haib17CEM4890_H75CGCCXY_SL263652    0.000028
# haib17CEM4890_H75CGCCXY_SL263722    0.000000
# haib17CEM4890_H75CGCCXY_SL263711    0.000000
# haib17CEM4890_H75CGCCXY_SL263637    0.000000
# haib17CEM4890_H75CGCCXY_SL263724    0.000000
# haib17CEM4890_H75CGCCXY_SL263640    0.000025
# haib17CEM4890_H75CGCCXY_SL263688    0.000000
# haib17CEM4890_H75CGCCXY_SL263709    0.000417
# haib17CEM4890_H75CGCCXY_SL263699    0.000000
# haib17DB4959_HMGW3CCXY_SL342492     0.399756
# haib17DB4959_HMGW3CCXY_SL342495     0.134404
# haib17DB4959_HMGW3CCXY_SL342487     0.454243
# haib17DB4959_HMCMJCCXY_SL336158     0.395956
# haib17DB4959_HMGW3CCXY_SL342498     0.297917
# haib17CEM4890_H75CGCCXY_SL263649    0.000000
# haib17DB4959_HMGW3CCXY_SL342499     0.123461
# haib17CEM4890_H75CGCCXY_SL263723    0.000000
# haib17DB4959_HMGW3CCXY_SL342491     0.383371
# haib17CEM4890_H75CGCCXY_SL263664    0.000000
# haib17CEM4890_H75CGCCXY_SL263710    0.000000
# haib17CEM4890_H75CGCCXY_SL263639    0.000000
# haib17CEM4890_H75CGCCXY_SL263685    0.000000
# haib17DB4959_HMGW3CCXY_SL342488     0.443824
# haib17CEM4890_H75CGCCXY_SL263663    0.000018
# haib17CEM4890_H75CGCCXY_SL263675    0.000000
# haib17CEM4890_H75CGCCXY_SL263697    0.000000
# haib17CEM4890_H75CGCCXY_SL263651    0.000000
# haib17CEM4890_H75CGCCXY_SL263712    0.000000
# haib17CEM4890_H75CGCCXY_SL263662    0.000000
# haib17DB4959_HMGW3CCXY_SL342490     0.457488
# haib17DB4959_HMGW3CCXY_SL342486     0.051486
# Name: Bradyrhizobium sp. BTAi1, dtype: float64

# %%
from scipy.cluster.hierarchy import linkage, cophenet, leaves_list
from scipy.spatial.distance import squareform, pdist

taxa = core_tabler.taxonomy()
prevalence = (taxa > 0).sum().sort_values()

taxa_order_prev = list(prevalence[prevalence >= 10].index)

FNAME = '.taxa_jaccard_cache.csv'
if isfile(FNAME):
    taxa_jaccard = pd.read_csv(FNAME, index_col=0)
else:
    btaxa = (taxa > 0).T
    distm = squareform(pdist(btaxa, metric='jaccard'))
    taxa_jaccard = pd.DataFrame(distm, index=btaxa.index, columns=btaxa.index)
    taxa_jaccard.to_csv(FNAME)
    

Z = linkage(squareform(taxa_jaccard), 'average')
print(cophenet(Z, squareform(taxa_jaccard))[0])
taxa_order = taxa.columns[leaves_list(Z)]
    
taxa_jaccard_long = taxa_jaccard.copy()
taxa_jaccard_long['taxa'] = taxa_jaccard_long.index
taxa_jaccard_long = taxa_jaccard_long.melt(id_vars=['taxa'])
taxa_jaccard_long_sub = taxa_jaccard_long.sample(n=100000)
taxa_jaccard_long.head()
# Out:
# 0.9758963373606443
#                          taxa                variable     value
# 0      Enterobacter sp. FY-07  Enterobacter sp. FY-07  0.000000
# 1     Enterobacter sp. R4-368  Enterobacter sp. FY-07  0.338315
# 2        Enterobacter sp. 638  Enterobacter sp. FY-07  0.480758
# 3  Enterobacter sp. CRENT-193  Enterobacter sp. FY-07  0.766370
# 4        Enterobacter sp. E20  Enterobacter sp. FY-07  0.554315

# %%
# %%R -i taxa_jaccard_long -i taxa_order_prev -w 1080 -h 1080
#
# taxa_jaccard_long$taxa = ordered(
#     taxa_jaccard_long$taxa,
#     levels=taxa_order_prev
# )
# taxa_jaccard_long$variable = ordered(
#     taxa_jaccard_long$variable,
#     levels=taxa_order_prev
# )
# taxa_jaccard_long$value = 1 - taxa_jaccard_long$value
#
# ggplot(taxa_jaccard_long, aes(x=taxa, y=variable, fill=value)) +
#     geom_tile() +
#     scale_fill_distiller(palette='Spectral', direction=-1) +
#     theme(
#         text = element_text(size=50),
#         panel.grid.major = element_blank(),
#         panel.grid.minor = element_blank(),
#         legend.position='right',
#         axis.text.x=element_blank(),
#         axis.title.x=element_blank(),
#         axis.text.y=element_blank(),
#         axis.title.y=element_blank(),
#     )

# %%
paths = core_tabler.pathways()

# %%
foo = paths[[col for col in paths.columns if 'unclassified' not in col and 'UNINTEGRATED' not in col]]
foo = (foo.T / foo.T.sum()).T.dropna()
100 * foo.mean().sort_values()
# Out:
# PWY-6748: nitrate reduction VII (denitrification)                                           1.156309e-07
# PWY-6344: L-ornithine degradation II (Stickland reaction)                                   2.666613e-07
# PWY-4202: arsenate detoxification I (glutaredoxin)                                          5.102388e-07
# PWY66-374: C20 prostanoid biosynthesis                                                      5.730439e-07
# PWY-7592: arachidonate biosynthesis III (metazoa)                                           5.859726e-07
# PWY-7053: docosahexaenoate biosynthesis I (lower eukaryotes)                                7.625804e-07
# PWY-7606: docosahexaenoate biosynthesis III (mammals)                                       8.716477e-07
# PWY-7036: very long chain fatty acid biosynthesis II                                        8.803369e-07
# MANNOSYL-CHITO-DOLICHOL-BIOSYNTHESIS: protein N-glycosylation (eukaryotic, high mannose)    1.090301e-06
# PWY-6433: hydroxylated fatty acid biosynthesis (plants)                                     1.618726e-06
# PWY-7399: methylphosphonate degradation II                                                  1.790396e-06
# PWY-7286: 7-(3-amino-3-carboxypropyl)-wyosine biosynthesis                                  1.836423e-06
# PWY-7283: wybutosine biosynthesis                                                           2.051951e-06
# PWY-7347: sucrose biosynthesis III                                                          2.273493e-06
# PWY-7270: L-methionine salvage cycle II (plants)                                            2.459381e-06
# ERGOSTEROL-SYN-PWY: superpathway of ergosterol biosynthesis I                               2.700657e-06
# PWY-6992: 1,5-anhydrofructose degradation                                                   2.792048e-06
# PWY-6351: D-myo-inositol (1,4,5)-trisphosphate biosynthesis                                 2.841301e-06
# PWY-6074: zymosterol biosynthesis                                                           3.009402e-06
# PWY-7238: sucrose biosynthesis II                                                           3.315887e-06
# PWY-6829: tRNA methylation (yeast)                                                          3.334641e-06
# PWY-7434: terminal O-glycans residues modification                                          3.455915e-06
# PWY-5499: vitamin B6 degradation                                                            3.688621e-06
# PWY-7546: diphthamide biosynthesis (eukaryotes)                                             3.873611e-06
# AEROBACTINSYN-PWY: aerobactin biosynthesis                                                  4.620253e-06
# PWY-6352: 3-phosphoinositide biosynthesis                                                   4.663533e-06
# PWY-6999: theophylline degradation                                                          4.685691e-06
# PWY-6863: pyruvate fermentation to hexanol                                                  4.874457e-06
# SUCSYN-PWY: sucrose biosynthesis I (from photosynthesis)                                    5.428291e-06
# PWY-5872: ubiquinol-10 biosynthesis (eukaryotic)                                            5.554600e-06
#                                                                                                 ...
# HISTSYN-PWY: L-histidine biosynthesis                                                       7.357388e-01
# PWY-3841: folate transformations II                                                         7.407552e-01
# COA-PWY-1: coenzyme A biosynthesis II (mammalian)                                           7.441447e-01
# PWY-3001: superpathway of L-isoleucine biosynthesis I                                       7.502784e-01
# PWY-5686: UMP biosynthesis                                                                  7.618888e-01
# TCA: TCA cycle I (prokaryotic)                                                              8.231952e-01
# PWY-7279: aerobic respiration II (cytochrome c) (yeast)                                     8.778924e-01
# PWY-6121: 5-aminoimidazole ribonucleotide biosynthesis I                                    9.028883e-01
# PWY0-166: superpathway of pyrimidine deoxyribonucleotides de novo biosynthesis (E. coli)    9.296951e-01
# PWY-7663: gondoate biosynthesis (anaerobic)                                                 9.691537e-01
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch)                            9.743894e-01
# PWY-7184: pyrimidine deoxyribonucleotides de novo biosynthesis I                            9.885970e-01
# PWY-5103: L-isoleucine biosynthesis III                                                     1.029445e+00
# PWY-7197: pyrimidine deoxyribonucleotide phosphorylation                                    1.033497e+00
# BRANCHED-CHAIN-AA-SYN-PWY: superpathway of branched amino acid biosynthesis                 1.093375e+00
# PWY-6122: 5-aminoimidazole ribonucleotide biosynthesis II                                   1.119304e+00
# PWY-6277: superpathway of 5-aminoimidazole ribonucleotide biosynthesis                      1.119304e+00
# PWY-7229: superpathway of adenosine nucleotides de novo biosynthesis I                      1.214523e+00
# PWY-6126: superpathway of adenosine nucleotides de novo biosynthesis II                     1.242682e+00
# PWY-6125: superpathway of guanosine nucleotides de novo biosynthesis II                     1.251132e+00
# PWY-7208: superpathway of pyrimidine nucleobases salvage                                    1.368756e+00
# ILEUSYN-PWY: L-isoleucine biosynthesis I (from threonine)                                   1.581686e+00
# PWY-7111: pyruvate fermentation to isobutanol (engineered)                                  1.742939e+00
# PWY-7221: guanosine ribonucleotides de novo biosynthesis                                    1.765976e+00
# PWY-7228: superpathway of guanosine nucleotides de novo biosynthesis I                      1.845933e+00
# VALSYN-PWY: L-valine biosynthesis                                                           1.903854e+00
# PWY-7219: adenosine ribonucleotides de novo biosynthesis                                    2.181167e+00
# PWY-7220: adenosine deoxyribonucleotides de novo biosynthesis II                            2.538222e+00
# PWY-7222: guanosine deoxyribonucleotides de novo biosynthesis II                            2.538222e+00
# PWY-3781: aerobic respiration I (cytochrome c)                                              3.407981e+00
# Length: 577, dtype: float64

# %%
# %%R
#
# brewer.pal(10, 'Set3')
# Out:
#  [1] "#8DD3C7" "#FFFFB3" "#BEBADA" "#FB8072" "#80B1D3" "#FDB462" "#B3DE69"
#  [8] "#FCCDE5" "#D9D9D9" "#BC80BD"
